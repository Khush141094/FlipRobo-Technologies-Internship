# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
File = pd.read_excel("C:/Users/s0116731/Desktop/New/New folder/Project-5/Customer_Retention_Dataset/customer_retention_dataset.xlsx" , sheet_name=None) #importing our Dataset.

# %%
File.keys()
# Out:
# dict_keys(['datasheet', 'codedsheet'])

# %%
DF =  File['datasheet'] 
DF1 = File['codedsheet']

# %%
df = DF.iloc[:,:47]
df_re = DF.iloc[:,47:]
df1 = DF1.iloc[:,:47]
df_re1 = DF1.iloc[:,47:]

# %%
df_re.columns = [x.upper() for x in ['From_the_following', 'Easy','Visual_appealing', 'variety','description','Fast_loading',
                                     'Reliability','Quickness','payment_options', 'Speedy_order_delivery ','Privacy','Security',
                                     'Perceived','Presence','Login_Time','Display_Time','price','page_loading_time',
                                     'mode_of_payment','Longer_delivery period', 'design','Frequent_disruption','efficient',
                                     'Recommendation']]

df_re1.columns = [x.upper() for x in ['From_the_following', 'Easy','Visual_appealing', 'variety','description','Fast_loading',
                                     'Reliability','Quickness','payment_options', 'Speedy_order_delivery ','Privacy','Security',
                                     'Perceived','Presence','Login_Time','Display_Time','price','page_loading_time',
                                     'mode_of_payment','Longer_delivery period', 'design','Frequent_disruption','efficient',
                                     'Recommendation']]

# %%
df_re
# Out:
#                                     FROM_THE_FOLLOWING  \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                                                   EASY  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ...

# %%
col = ['Gender','Age','City','Pin_Code','Vintage','No.of_purchase/year','Usage_of internet','Deviced_used','Screen_size_mobile_device','OS',
'Browser','Channel_access','how_do you_reach_onlinestore','Time_taken','Payment_option','Abandon','Reason_abandon','content_ease','product_comparison',
'information','seller_information','Ease_navigation', 'Loading_speed','UX','Payment_methods','transaction_time','Empathy','privacy','Responsiveness',
'benefit_and_discounts','Enjoyment','flexible','Return_replacement','Benefit','satisfaction_customers','User_derive_satisfaction','Net Benefit',
'trust','several_category','product_information','Monetary_savings','Patronizing','Adventure','social_status','gratification','fulfilment','value_for_m']

# %%
df.columns = [x.upper() for x in col]

df1.columns = [x.upper() for x in col]

# %%
df.isna().sum()
# Out:
# GENDER                          0
# AGE                             0
# CITY                            0
# PIN_CODE                        0
# VINTAGE                         0
# NO.OF_PURCHASE/YEAR             0
# USAGE_OF INTERNET               0
# DEVICED_USED                    0
# SCREEN_SIZE_MOBILE_DEVICE       0
# OS                              0
# BROWSER                         0
# CHANNEL_ACCESS                  0
# HOW_DO YOU_REACH_ONLINESTORE    0
# TIME_TAKEN                      0
# PAYMENT_OPTION                  0
# ABANDON                         0
# REASON_ABANDON                  0
# CONTENT_EASE                    0
# PRODUCT_COMPARISON              0
# INFORMATION                     0
# SELLER_INFORMATION              0
# EASE_NAVIGATION                 0
# LOADING_SPEED                   0
# UX                              0
# PAYMENT_METHODS                 0
# TRANSACTION_TIME                0
# EMPATHY                         0
# ...

# %%
df_re.isna().sum()
# Out:
# FROM_THE_FOLLOWING        0
# EASY                      0
# VISUAL_APPEALING          0
# VARIETY                   0
# DESCRIPTION               0
# FAST_LOADING              0
# RELIABILITY               0
# QUICKNESS                 0
# PAYMENT_OPTIONS           0
# SPEEDY_ORDER_DELIVERY     0
# PRIVACY                   0
# SECURITY                  0
# PERCEIVED                 0
# PRESENCE                  0
# LOGIN_TIME                0
# DISPLAY_TIME              0
# PRICE                     0
# PAGE_LOADING_TIME         0
# MODE_OF_PAYMENT           0
# LONGER_DELIVERY PERIOD    0
# DESIGN                    0
# FREQUENT_DISRUPTION       0
# EFFICIENT                 0
# RECOMMENDATION            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'CITY', 'PIN_CODE', 'VINTAGE', 'NO.OF_PURCHASE/YEAR',
#        'USAGE_OF INTERNET', 'DEVICED_USED', 'SCREEN_SIZE_MOBILE_DEVICE', 'OS',
#        'BROWSER', 'CHANNEL_ACCESS', 'HOW_DO YOU_REACH_ONLINESTORE',
#        'TIME_TAKEN', 'PAYMENT_OPTION', 'ABANDON', 'REASON_ABANDON',
#        'CONTENT_EASE', 'PRODUCT_COMPARISON', 'INFORMATION',
#        'SELLER_INFORMATION', 'EASE_NAVIGATION', 'LOADING_SPEED', 'UX',
#        'PAYMENT_METHODS', 'TRANSACTION_TIME', 'EMPATHY', 'PRIVACY',
#        'RESPONSIVENESS', 'BENEFIT_AND_DISCOUNTS', 'ENJOYMENT', 'FLEXIBLE',
#        'RETURN_REPLACEMENT', 'BENEFIT', 'SATISFACTION_CUSTOMERS',
#        'USER_DERIVE_SATISFACTION', 'NET BENEFIT', 'TRUST', 'SEVERAL_CATEGORY',
#        'PRODUCT_INFORMATION', 'MONETARY_SAVINGS', 'PATRONIZING', 'ADVENTURE',
#        'SOCIAL_STATUS', 'GRATIFICATION', 'FULFILMENT', 'VALUE_FOR_M'],
#       dtype='object')

# %%
df_Customer_details_columns = df[['GENDER', 'AGE', 'CITY', 'PIN_CODE', 'VINTAGE', 'NO.OF_PURCHASE/YEAR',
       'USAGE_OF INTERNET', 'DEVICED_USED', 'SCREEN_SIZE_MOBILE_DEVICE', 'OS',
       'BROWSER', 'CHANNEL_ACCESS']]

df_Customer_details_columns1 = df1[['GENDER', 'AGE', 'CITY', 'PIN_CODE', 'VINTAGE', 'NO.OF_PURCHASE/YEAR',
       'USAGE_OF INTERNET', 'DEVICED_USED', 'SCREEN_SIZE_MOBILE_DEVICE', 'OS',
       'BROWSER', 'CHANNEL_ACCESS']]

df_ecom_details_columns = df[['HOW_DO YOU_REACH_ONLINESTORE',
       'TIME_TAKEN', 'PAYMENT_OPTION', 'ABANDON', 'REASON_ABANDON',
       'CONTENT_EASE', 'PRODUCT_COMPARISON', 'INFORMATION',
       'SELLER_INFORMATION', 'EASE_NAVIGATION', 'LOADING_SPEED', 'UX',
       'PAYMENT_METHODS', 'TRANSACTION_TIME']]

df_ecom_details_columns1 = df1[['HOW_DO YOU_REACH_ONLINESTORE',
       'TIME_TAKEN', 'PAYMENT_OPTION', 'ABANDON', 'REASON_ABANDON',
       'CONTENT_EASE', 'PRODUCT_COMPARISON', 'INFORMATION',
       'SELLER_INFORMATION', 'EASE_NAVIGATION', 'LOADING_SPEED', 'UX',
       'PAYMENT_METHODS', 'TRANSACTION_TIME']]

df_Customer_Success_details_columns = df[['EMPATHY', 'PRIVACY',
       'RESPONSIVENESS', 'BENEFIT_AND_DISCOUNTS', 'ENJOYMENT', 'FLEXIBLE',
       'RETURN_REPLACEMENT', 'BENEFIT', 'SATISFACTION_CUSTOMERS',
       'USER_DERIVE_SATISFACTION', 'NET BENEFIT', 'TRUST', 'SEVERAL_CATEGORY',
       'PRODUCT_INFORMATION']]

df_Customer_Success_details_columns1 = df1[['EMPATHY', 'PRIVACY',
       'RESPONSIVENESS', 'BENEFIT_AND_DISCOUNTS', 'ENJOYMENT', 'FLEXIBLE',
       'RETURN_REPLACEMENT', 'BENEFIT', 'SATISFACTION_CUSTOMERS',
       'USER_DERIVE_SATISFACTION', 'NET BENEFIT', 'TRUST', 'SEVERAL_CATEGORY',
       'PRODUCT_INFORMATION']]

df_Customer_Gratifications_columns = df[['MONETARY_SAVINGS', 'PATRONIZING', 'ADVENTURE',
       'SOCIAL_STATUS', 'GRATIFICATION', 'FULFILMENT']]

df_Customer_Gratifications_columns1 = df1[['MONETARY_SAVINGS', 'PATRONIZING', 'ADVENTURE',
       'SOCIAL_STATUS', 'GRATIFICATION', 'FULFILMENT']]

df_Hedonic_value_column = df['VALUE_FOR_M']

df_Hedonic_value_column1 = df1['VALUE_FOR_M']

# %%
collist = df_Customer_details_columns.columns.values
collist = np.delete(collist, [2,3])
plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(4,3,i+1)
    df[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %%
plt.figure(figsize=(12,2))
df_Customer_details_columns['CITY'].hist()
plt.title('CITY')
plt.ylabel('Count')
plt.show()

# %%
collist = df_ecom_details_columns.columns.values

plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(5,3,i+1)
    df[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %%
collist = df_Customer_Success_details_columns.columns.values

plt.figure(figsize=(20,10))
  
for i in range(0,len(collist)):
    plt.subplot(5,3,i+1)
    df[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %%
collist = df_Customer_Gratifications_columns.columns.values

plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(4,3,i+1)
    df[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %%
plt.figure(figsize=(5,5))
df_Hedonic_value_column.hist()
plt.title('VALUE_FOR_MONEY_SPENT')
plt.ylabel('Count')
plt.show()

# %%
df_re.replace(['Amazon.com','Amazon.com, Flipkart.com','Amazon.com, Flipkart.com, Myntra.com',
               'Amazon.com, Flipkart.com, Paytm.com','Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal',
               'Amazon.com, Paytm.com, Myntra.com','Amazon.in','Amazon.in, Flipkart.com','Amazon.in, Flipkart.com, Myntra.com',
               'Amazon.in, Flipkart.com, Myntra.com, Snapdeal','Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
               'Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com','Amazon.in, Flipkart.com, Paytm.com',
               'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com','Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
               'Amazon.in, Flipkart.com, Snapdeal.com', 'Amazon.in, Myntra.com', 'Amazon.in, Myntra.com, Snapdeal.com',
               'Amazon.in, Patym.com', 'Amazon.in, Paytm.com', 'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Snapdeal',
               'Amazon.in, Snapdeal.com', 'Flipkart.com', 'Flipkart.com, Myntra.com', 'Flipkart.com, Myntra.com, Snapdeal',
               'Flipkart.com, Myntra.com, Snapdeal.com', 'Flipkart.com, Paytm.com', 'Flipkart.com, Paytm.com, Myntra.com, snapdeal.com',
               'Flipkart.com, Paytm.com, Snapdeal.com', 'Flipkart.com, Snapdeal.com', 'Myntra.com','Myntra.com, Snapdeal.com',
               'Patym.com', 'Patym.com, Myntra.com', 'Paytm.com', 'Paytm.com, Snapdeal.com', 'Paytm.com, snapdeal.com',
               'Snapdeal.com', 'snapdeal.com'] , ['A','A, F','A, F, M','A, F, P','A, F, P, M, S','A, P, M','A','A, F',
               'A, F, M','A, F, M, S', 'A, F, M, S', 'A, F, P, M, S', 'A, F, P', 'A, F, P, M, S', 'A, F, P, S', 'A, F, S',
               'A, M', 'A, M, S', 'A, P', 'A, P', 'A, P, M', 'A, S', 'A, S', 'F', 'F, M', 'F, M, S', 'F, M, S', 'F, P',
               'F, P, M, S', 'F, P, S', 'F, S', 'M', 'M, S', 'P', 'P, M', 'P', 'P, S', 'P, S', 'S', 'S'] , inplace = True)

# replacing the all the names of the E-commerse website with the starting letter of the easier understanding.

# %%
coll = df_re.columns.values
coll1 = coll[:12]
coll2 = coll[12:]
plt.figure(figsize=(20,10))
collist = coll1
for i in range(0,len(collist)):
    plt.subplot(4,3,i+1)
    df_re[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.xticks(rotation = 90)
    plt.ylabel('Count')
    plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
collist = coll2
for i in range(0,len(collist)):
    plt.subplot(4,3,i+1)
    df_re[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.xticks(rotation = 90)
    plt.ylabel('Count')
    plt.tight_layout()

# %%
collist = df_Customer_details_columns1.columns.values
collist = np.delete(collist, [2,3])
for i in collist:
    facet= sns.FacetGrid(df1,col='VALUE_FOR_M')
    facet.map(sns.distplot,i,color = "#345434")
    plt.show()

# %%
cor = df_Customer_details_columns1.join(df_Hedonic_value_column1)
plt.figure(figsize=(15,7))
cor.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Features with the target column", fontsize=25)
plt.show()

# %%
COR=pd.DataFrame(cor.corr()['VALUE_FOR_M'].sort_values(ascending=False)).drop(['VALUE_FOR_M'])
print("KEY OBSERVATIONS:\n ")
COR
# Out:
# KEY OBSERVATIONS:
#                            VALUE_FOR_M
# GENDER                        0.202014
# NO.OF_PURCHASE/YEAR           0.196359
# OS                            0.193282
# VINTAGE                       0.175901
# PIN_CODE                      0.127763
# AGE                           0.052869
# USAGE_OF INTERNET            -0.022531
# DEVICED_USED                 -0.039320
# CHANNEL_ACCESS               -0.127264
# BROWSER                      -0.277167
# SCREEN_SIZE_MOBILE_DEVICE    -0.295416

# %%
collist = df_ecom_details_columns.columns.values

for i in collist:
    facet= sns.FacetGrid(df1,col='VALUE_FOR_M')
    facet.map(sns.distplot,i,color = "#345434")
    plt.show()

# %%
cor = df_ecom_details_columns1.join(df_Hedonic_value_column1)
plt.figure(figsize=(15,7))
cor.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Features with the target column", fontsize=25)
plt.show()

# %%
COR=pd.DataFrame(cor.corr()['VALUE_FOR_M'].sort_values(ascending=False)).drop(['VALUE_FOR_M'])
print("KEY OBSERVATIONS:\n ")
COR
# Out:
# KEY OBSERVATIONS:
#                               VALUE_FOR_M
# ABANDON                          0.352733
# EASE_NAVIGATION                  0.284420
# HOW_DO YOU_REACH_ONLINESTORE     0.268103
# SELLER_INFORMATION               0.261774
# PRODUCT_COMPARISON               0.237717
# TIME_TAKEN                       0.223296
# PAYMENT_OPTION                   0.156306
# CONTENT_EASE                     0.154706
# LOADING_SPEED                    0.123938
# REASON_ABANDON                   0.110843
# UX                               0.097268
# PAYMENT_METHODS                  0.095558
# TRANSACTION_TIME                -0.001687
# INFORMATION                     -0.131604

# %%
collist =df_Customer_Success_details_columns.columns.values

for i in collist:
    facet= sns.FacetGrid(df1,col='VALUE_FOR_M')
    facet.map(sns.distplot,i,color = "#345434")
    plt.show()

# %%
cor = df_Customer_Success_details_columns1.join(df_Hedonic_value_column1)
plt.figure(figsize=(15,7))
cor.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Fetures with the target column", fontsize=25)
plt.show()

# %%
COR=pd.DataFrame(cor.corr()['VALUE_FOR_M'].sort_values(ascending=False)).drop(['VALUE_FOR_M'])
print("KEY OBSERVATIONS:\n ")
COR
# Out:
# KEY OBSERVATIONS:
#                           VALUE_FOR_M
# USER_DERIVE_SATISFACTION     0.513614
# NET BENEFIT                  0.451091
# PRODUCT_INFORMATION          0.347117
# TRUST                        0.289592
# BENEFIT                      0.261204
# EMPATHY                      0.253112
# BENEFIT_AND_DISCOUNTS        0.250499
# ENJOYMENT                    0.243081
# SATISFACTION_CUSTOMERS       0.199695
# RETURN_REPLACEMENT           0.174047
# SEVERAL_CATEGORY             0.153377
# FLEXIBLE                     0.136939
# PRIVACY                      0.034751
# RESPONSIVENESS              -0.028370

# %%
collist = df_Customer_Gratifications_columns1.columns.values

for i in collist:
    facet= sns.FacetGrid(df1,col='VALUE_FOR_M')
    facet.map(sns.distplot,i,color = "#345434")
    plt.show()

# %%
cor = df_Customer_Gratifications_columns1.join(df_Hedonic_value_column1)
plt.figure(figsize=(15,7))
cor.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Fetures with the target column", fontsize=25)
plt.show()

# %%
COR=pd.DataFrame(cor.corr()['VALUE_FOR_M'].sort_values(ascending=False)).drop(['VALUE_FOR_M'])
print("KEY OBSERVATIONS:\n ")
COR
# Out:
# KEY OBSERVATIONS:
#                   VALUE_FOR_M
# GRATIFICATION        0.473175
# MONETARY_SAVINGS     0.352887
# PATRONIZING          0.246690
# ADVENTURE            0.208436
# FULFILMENT           0.110095
# SOCIAL_STATUS       -0.017987

# %%
encode = {'A':1,
'A, F':6,
'A, F, M':7,
'A, F, M, S':8,
'A, F, P':9,
'A, F, P, M, S':10,
'A, F, P, S':11,
'A, F, S':12,
'A, M':13,
'A, M, S':14,
'A, P':15,
'A, P, M':16,
'A, S':17,
'F':2,
'F, M':18,
'F, M, S':19,
'F, P':20,
'F, P, M, S':21,
'F, P, S':22,
'F, S':23,
'M':3,
'M, S':24,
'P':4,
'P, M':25,
'P, S':26,
'S':5}

# %%
for i in df_re.columns:
    df_re[i] = df_re[i].replace(encode)

df_re.head()
# Out:
#    FROM_THE_FOLLOWING  EASY  VISUAL_APPEALING  VARIETY  DESCRIPTION  \
# 0                  15     4                 2        2            5
# 1                   8     8                13       18            7
# 2                  16    16                16       13           16
# 3                  10    10                10        6            6
# 4                  10    10                 3        3           10
#
#    FAST_LOADING  RELIABILITY  QUICKNESS  PAYMENT_OPTIONS  \
# 0             5            4          4                4
# 1             7            3          7                7
# 2            15           16         16               25
# 3            12            9          9                7
# 4             1           16         10               10
#
#    SPEEDY_ORDER_DELIVERY   ...  LOGIN_TIME  DISPLAY_TIME  PRICE  \
# 0                       1  ...           1             1      2
# 1                       6  ...           6             3      5
# ...

# %%
df_re.T.plot.barh(stacked = True, figsize=(20,8))
plt.legend(encode, bbox_to_anchor=(1.05,1))
plt.xlabel("Amazon - A, Flipkart - F, Myntra - M, Paytm - P, Snapdeal - S", fontsize = 20 )
plt.ylabel("Parameters of Measure", fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_Customer_details_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_ecom_details_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_Customer_Success_details_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df_Customer_Gratifications_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
plt.figure(figsize=(15,5))
df1.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of all Features with the Target column", fontsize=25)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_re.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
cor = df_re.join(df_Hedonic_value_column1)
plt.figure(figsize=(15,7))
cor.corr()['VALUE_FOR_M'].sort_values(ascending=False).drop(['VALUE_FOR_M']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Fetures with the target column", fontsize=25)
plt.show()

# %%
#Summary:

#The ease of usage of internet which includes the device used browser and internet the attractiveness of the web application/mobile application with convenience of ordering the product along with the Customer Support with Gratification makes a customer to be a repeated user.

#The Customer Gratification that can be increased to make the customer feel that he is valued which directly increases the repeated usage.

# %%
#Conclusion:

#E-commerce has transformed the way business is done in India. The Indian E-commerce market is expected to grow to US dollars 200 billion by 2026 from US dollars 38.5 billion as of 2021. Much of the growth for the industry has been triggered by an increase in internet and smart phone penetration, in such a market a customer can be a repeated user in depending on the factors as seen above and these factors are summarized into two such as Hedonic value and Utilitatian value. Improvement on these factors a Organization will be a leader in E-Commerce business in India.
